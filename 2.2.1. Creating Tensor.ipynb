# %%
#!conda install --yes numpy
#!conda install pytorch

# %%
# p.71 Creating Tensor /20191226 / Seongtae Kim 

import torch, numpy as np

# list로부터 2x3 텐서 생성
x_list = [[1,2,3], [4,5,6]]
x = torch.Tensor(x_list)
print(x)

# numpy array로부터 2x3 텐서 생성
x_numpy = np.array([[1, 2, 3],[4, 5, 6]])
x = torch.Tensor(np.array([[9, 6, 1],[5, 3, 2]]))
print(x)
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])
# tensor([[9., 6., 1.],
#         [5., 3., 2.]])

# %%
# .tolist() ---> list타입으로 형변환
x_back2list =x.tolist()
print(type(x_back2list))

# .numpy() ---> numpy타입으로 형변환
x_back2numpy = x.numpy()
print(type(x_back2numpy))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
#!pip install pycuda
# Out:
# ...
#      |████████████████████████████████| 1.6MB 583kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61kB 18.2MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 471kB 19.9MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /home/seongtae/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-7pbpd_qj/pycuda/setup.py'"'"'; __file__='"'"'/tmp/pip-install-7pbpd_qj/pycuda/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-ddm8e_70 --python-tag cp37
#        cwd: /tmp/pip-install-7pbpd_qj/pycuda/
#   Complete output (102 lines):
#   ***************************************************************
#   *** WARNING: nvcc not in path.
#   *** May need to set CUDA_INC_DIR for installation to succeed.
# ...

# %%
# 기본적으로 텐서 생성시 CPU의 상태 디바이스 정보를 포함한다.
print(x.device)

#cuda가 없을 시 !pip install pycuda로 설치
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#GPU 사용
x = x.to(device)
print(x.device)

device='cpu'
#CPU 사용
x = x.to(device)
print(x.device)
# Out:
# cpu
# cpu
# cpu
